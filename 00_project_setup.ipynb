# %% [markdown]
# # Crypto Quantitative Analysis & Blockchain Infrastructure
# ### Project Initialization & Environment Setup
#
# **Project Overview:**
# - Ingests and processes on-chain data from decentralized finance (DeFi) protocols.
# - Implements quantitative analysis techniques for signal generation.
# - Develops and backtests algorithmic crypto trading strategies.
#
# **Project Structure:**
# | Phase | Component | Description |
# |---|----------|----------------|
# | 00 | `00_project_setup.ipynb` | Environment configuration and directory initialization |
# | 01 | `01_blockchain_basics.ipynb` | Custom Python blockchain implementation |
# | 02 | `02_onchain_data.ipynb` | Ethereum/DeFi data pipeline via public APIs |
# | 03 | `03_quant_analysis.ipynb` | Quantitative signal processing |
# | 04 | `04_backtest_strategy.ipynb` | Strategy backtesting and performance evaluation |

# %% [markdown]
# ## 1. Mount Google Drive Volume

# %%
from google.colab import drive

drive.mount('/content/drive')
print('Drive volume mounted.')
# Out:
# Mounted at /content/drive
# ✅ Google Drive mounted successfully

# %% [markdown]
# ## 2. Initialize Directory Structure

# %%
import os

ROOT_DIR = '/content/drive/MyDrive/crypto_quant_project'

directories = [
    ROOT_DIR,
    os.path.join(ROOT_DIR, 'notebooks'),
    os.path.join(ROOT_DIR, 'data', 'raw'),
    os.path.join(ROOT_DIR, 'data', 'processed'),
    os.path.join(ROOT_DIR, 'data', 'cache'),
    os.path.join(ROOT_DIR, 'models'),
    os.path.join(ROOT_DIR, 'results'),
    os.path.join(ROOT_DIR, 'utils'),
]

for directory in directories:
    os.makedirs(directory, exist_ok=True)
    print(f'Initialized: {directory}')

print('\nDirectory structure successfully created.')
# Out:
# 📁 Created: /content/drive/MyDrive/crypto_quant_project
# 📁 Created: /content/drive/MyDrive/crypto_quant_project/notebooks
# 📁 Created: /content/drive/MyDrive/crypto_quant_project/data/raw
# 📁 Created: /content/drive/MyDrive/crypto_quant_project/data/processed
# 📁 Created: /content/drive/MyDrive/crypto_quant_project/data/cache
# 📁 Created: /content/drive/MyDrive/crypto_quant_project/models
# 📁 Created: /content/drive/MyDrive/crypto_quant_project/results
# 📁 Created: /content/drive/MyDrive/crypto_quant_project/utils
#
# ✅ All folders created!

# %% [markdown]
# ## 3. Dependency Installation

# %%
# %pip install -q pandas numpy matplotlib seaborn
# %pip install -q ccxt pycoingecko
# %pip install -q web3 requests
# %pip install -q backtesting plotly

print('\nDependencies installed.')
# Out:
# Installing packages... (this takes ~1 minute)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.0/142.0 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 84.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 63.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.8/223.8 kB 16.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 37.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.5/587.5 kB 32.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.5/102.5 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.6/343.6 kB 21.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.0/176.0 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 70.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 4. Environment Verification

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ccxt
import requests
from pycoingecko import CoinGeckoAPI
from web3 import Web3
import plotly.graph_objects as go

print('pandas     :', pd.__version__)
print('numpy      :', np.__version__)
print('ccxt       :', ccxt.__version__)
print('web3       :', Web3.api_version if hasattr(Web3, "api_version") else 'ok')
print('plotly     : ok')
print('pycoingecko: ok')
print('\nEnvironment verification complete.')
# Out:
# pandas     : 2.2.2
# numpy      : 2.0.2
# ccxt       : 4.5.49
# web3       : ok
# plotly     : ok
# pycoingecko: ok
#
# ✅ All imports successful — ready to start!

# %% [markdown]
# ## 5. Generate Configuration File

# %%
config_code = '''
import os

# Project path configurations
ROOT = "/content/drive/MyDrive/crypto_quant_project"

RAW_DATA      = f"{ROOT}/data/raw"
PROCESSED_DATA = f"{ROOT}/data/processed"
CACHE_DIR     = f"{ROOT}/data/cache"
RESULTS_DIR   = f"{ROOT}/results"
MODELS_DIR    = f"{ROOT}/models"

# Asset specifications
COINS = ["bitcoin", "ethereum", "solana"]
SYMBOLS = ["BTC/USDT", "ETH/USDT", "SOL/USDT"]

# Temporal parameters
LOOKBACK_DAYS = 365

# Node endpoints
ETH_RPC_URL = "https://cloudflare-eth.com"
'''

config_path = f'{ROOT_DIR}/utils/config.py'
with open(config_path, 'w') as f:
    f.write(config_code)

print(f'Configuration file generated at: {config_path}')
# Out:
# ✅ Config file written to: /content/drive/MyDrive/crypto_quant_project/utils/config.py

# %% [markdown]
# ## 6. Data Ingestion Test

# %%
from pycoingecko import CoinGeckoAPI
import pandas as pd

cg = CoinGeckoAPI()

btc_data = cg.get_price(
    ids='bitcoin',
    vs_currencies='usd',
    include_market_cap='true',
    include_24hr_change='true'
)

price = btc_data['bitcoin']['usd']
market_cap = btc_data['bitcoin']['usd_market_cap']
change_24h = btc_data['bitcoin']['usd_24h_change']

print('--- Market Data Sample (BTC) ---')
print(f'Price:       ${price:,.2f}')
print(f'Market Cap:  ${market_cap/1e9:,.1f}B')
print(f'24h Change:  {change_24h:+.2f}%')
print('\nData ingestion test successful.')
# Out:
# === LIVE BITCOIN DATA ===
# Price:       $75,498.00
# Market Cap:  $1,512.0B
# 24h Change:  -0.77%
#
# ✅ Live data working — project is fully set up!

# %% [markdown]
# ## System Readiness Confirmed
#
# The workspace environment, local dependencies, external API connections, and standardized project directories have been successfully established. Proceed to `01_blockchain_basics.ipynb` for the core blockchain implementation.
